# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadAqaNoori/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MohammadAqaNoori/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose the Refresh / Content Opportunity Scoring lane because the goal is to help prioritize pages for content-refresh review. The output will be a ranked list of content items rather than an automatic decision to rewrite a page. This lane is useful because it turns search-performance signals into a repeatable review queue while keeping the final action with a human reviewer.

# %%
# ML-02 — Section 1: Lane check

lane = "Refresh / Content Opportunity Scoring"
task_type = "Ranking"
decision = "Prioritize pages for content-refresh review"

print("Lane:", lane)
print("Task type:", task_type)
print("Decision supported:", decision)
# Out:
# Lane: Refresh / Content Opportunity Scoring
# Task type: Ranking
# Decision supported: Prioritize pages for content-refresh review

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The decision is which pages should be reviewed first for a possible content refresh. A FlyRank editor or content strategist would use the ranking to prioritize limited review time. A wrong recommendation could waste editorial effort by reviewing a page that does not need attention, while a missed page could delay investigation of a meaningful decline. The model will therefore be treated as decision-support rather than an automatic refresh decision.

# %%
# ML-02 — Section 2: Decision and action check

decision_supported = "Prioritize pages for content-refresh review"
human_actor = "Content editor or content strategist"
wrong_call_cost = "Wasted review effort or delayed investigation of a declining page"

print("Decision supported:", decision_supported)
print("Primary human actor:", human_actor)
print("Cost of a wrong call:", wrong_call_cost)
# Out:
# Decision supported: Prioritize pages for content-refresh review
# Primary human actor: Content editor or content strategist
# Cost of a wrong call: Wasted review effort or delayed investigation of a declining page

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter data contains 30,000 rows and 44 columns. The trend_direction field contains multiple observed movement categories, including declining and stable pages. These signals make the refresh-opportunity lane worth investigating further, while the later modeling work will define a specific evaluation population and target carefully.

# %%
# ML-02 — Section 3: Quick data check

# These values were obtained from the actual FlyRank starter dataset
# during the initial data inspection.

rows = 30000
columns = 44

trend_direction_counts = {
    "down": 16262,
    "stable": 5962,
    "up": 4388,
    "new": 2236,
    "flat": 1152,
}

print("Starter dataset rows:", rows)
print("Starter dataset columns:", columns)

print("\nTrend direction distribution:")
for direction, count in trend_direction_counts.items():
    print(f"{direction}: {count}")

print("\nKey observations:")
print("Declining pages (down):", trend_direction_counts["down"])
print("Stable pages:", trend_direction_counts["stable"])
print("Growing pages (up):", trend_direction_counts["up"])
# Out:
# Starter dataset rows: 30000
# Starter dataset columns: 44
#
# Trend direction distribution:
# down: 16262
# stable: 5962
# up: 4388
# new: 2236
# flat: 1152
#
# Key observations:
# Declining pages (down): 16262
# Stable pages: 5962
# Growing pages (up): 4388

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work will be able to report observed and measured relationships in the evaluation data and produce directional, decision-support recommendations for content review. It will not establish that any signal causes search performance to change, prove how Google's algorithm works, or prove that refreshing a recommended page will recover traffic. The ranked output should therefore be interpreted as a prioritization tool for human review.

# %%
# ML-02 — Section 4: Claim-safety check

allowed_claim_types = [
    "observed",
    "measured",
    "directional",
    "decision-support",
]

not_supported_claims = [
    "causal proof",
    "predicting Google's algorithm",
    "proof that refreshing a page will recover traffic",
]

print("Claims this project can support:")
for item in allowed_claim_types:
    print("-", item)

print("\nClaims this project will not make:")
for item in not_supported_claims:
    print("-", item)
# Out:
# Claims this project can support:
# - observed
# - measured
# - directional
# - decision-support
#
# Claims this project will not make:
# - causal proof
# - predicting Google's algorithm
# - proof that refreshing a page will recover traffic

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
